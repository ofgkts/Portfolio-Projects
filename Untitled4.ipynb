# %% [markdown]
# <a href="https://colab.research.google.com/github/ofgkts/Portfolio-Projects/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd

# %%
df=pd.read_excel("/content/drive/MyDrive/proje/Omer Code/projects/Enterprises_Turkey/data.xlsx")

# %%
df.head()
# Out:
#                                           Unnamed: 0  \
# 0                                                NaN
# 1                                                NaN
# 2           NACE Rev. 2, Kısım\nNACE Rev. 2, Section
# 3                                    Türkiye\nTurkey
# 4  B - Madencilik ve taşocakçılığı \nMining and q...
#
#                                        Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                             NaN        NaN        NaN
# 1                                             NaN        NaN        NaN
# 2  Bölüm,grup ve sınıf \nDivision,group and class       2009       2010
# 3                     Genel toplam\nGeneral total    2631085    2678787
# 4                                    Toplam-Total       3963       4128
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %% [markdown]
# - damn that's a bit dirty data but i think this is it this will be good

# %% [markdown]
# Cleaning cleaning aaannd more cleaning time

# %%
#drop the first two row it is unnecessary
df=df.iloc[2:]
#if i need it i will sum while visualizing so drop general total
df = df.drop(3)

# %%
df.columns=df.iloc[0]
df=df[1:]
df.head(45)
# Out:
# 2            NACE Rev. 2, Kısım\nNACE Rev. 2, Section  \
# 4   B - Madencilik ve taşocakçılığı \nMining and q...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# ...

# %%
#i need to fill empty following rows with the not null one and it is simple solution just ffil method
df['NACE Rev. 2, Kısım\nNACE Rev. 2, Section']=df['NACE Rev. 2, Kısım\nNACE Rev. 2, Section'].fillna(method='ffill')
#drop the grand total one i could calculate if i need but at this point its just unnecessary
df_cleaned = df[df['Bölüm,grup ve sınıf \nDivision,group and class'] != 'Toplam-Total']
df_cleaned.head(45)

# %%
df_cleaned['Bölüm,grup ve sınıf \nDivision,group and class'].value_counts()
# Out:
# 05      1
# 5221    1
# 4939    1
# 494     1
# 4941    1
#        ..
# 2752    1
# 279     1
# 2790    1
# 28      1
#         1
# Name: Bölüm,grup ve sınıf \nDivision,group and class, Length: 844, dtype: int64
