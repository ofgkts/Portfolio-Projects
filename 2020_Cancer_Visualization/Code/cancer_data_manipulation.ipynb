# %%
import pandas as pd 
import numpy as np

cancer=pd.read_csv('cancer_data(merged_raw).csv' ,index_col=False)
df=cancer.copy()
df.head()
# Out:
#    Rank        Cancer Newcasesin2020  %ofallcancers FEMALE_CASE  \
# 0   NaN  All cancers*     18,094,716            NaN   8,751,759
# 1   1.0        Breast      2,261,419           12.5   2,261,419
# 2   2.0          Lung      2,261,771           12.2     770,828
# 3   3.0  Colorectal**      1,931,590           10.7         NaN
# 4   4.0      Prostate      1,414,259            7.8         NaN
#
#    Female_Percentege  Male_Case  Male_Percentege
# 0                NaN  9,342,957              NaN
# 1               25.8        NaN              NaN
# 2                8.8  1,435,943             15.4
# 3                NaN  1,065,960             11.4
# 4                NaN  1,414,259             15.1

# %% [markdown]
# ## this is my second time doing this. first one is gone because of my 10 years old pc so
# # to do list
# ## get rid of first index column
# ## some columns is in wrong type change that
# ## fill the null rows
# ## and maybe change some columns name

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               34 non-null     float64
#  1   Cancer             35 non-null     object
#  2   Newcasesin2020     35 non-null     object
#  3   %ofallcancers      34 non-null     float64
#  4   FEMALE_CASE        30 non-null     object
#  5   Female_Percentege  29 non-null     float64
#  6   Male_Case          28 non-null     object
#  7   Male_Percentege    27 non-null     float64
# dtypes: float64(4), object(4)
# memory usage: 2.3+ KB

# %%
df.isna().sum()
# Out:
# Rank                 1
# Cancer               0
# Newcasesin2020       0
# %ofallcancers        1
# FEMALE_CASE          5
# Female_Percentege    6
# Male_Case            7
# Male_Percentege      8
# dtype: int64

# %%
df['%ofallcancers']=df['%ofallcancers'].fillna(100)
df.fillna(0,inplace=True)
df.isna().sum()
# Out:
# Rank                 0
# Cancer               0
# Newcasesin2020       0
# %ofallcancers        0
# FEMALE_CASE          0
# Female_Percentege    0
# Male_Case            0
# Male_Percentege      0
# dtype: int64

# %%
df.iloc[:,:]
# Out:
#     Rank                         Cancer Newcasesin2020  %ofallcancers  \
# 0    0.0                   All cancers*     18,094,716          100.0
# 1    1.0                         Breast      2,261,419           12.5
# 2    2.0                           Lung      2,261,771           12.2
# 3    3.0                   Colorectal**      1,931,590           10.7
# 4    4.0                       Prostate      1,414,259            7.8
# 5    5.0                        Stomach      1,089,103            6.0
# 6    6.0                          Liver        905,677            5.0
# 7    7.0                   Cervix uteri        604,127            3.3
# 8    8.0                     Oesophagus        604,100            3.3
# 9    9.0                        Thyroid        586,202            3.2
# 10  10.0                        Bladder        573,278            3.2
# 11  11.0           Non-Hodgkin lymphoma        544,352            3.0
# ...

# %%
df['Newcasesin2020']=df['Newcasesin2020'].str.replace(",","")

# %%
df.head()
# Out:
#    Rank        Cancer Newcasesin2020  %ofallcancers FEMALE_CASE  \
# 0   0.0  All cancers*       18094716          100.0   8,751,759
# 1   1.0        Breast        2261419           12.5   2,261,419
# 2   2.0          Lung        2261771           12.2     770,828
# 3   3.0  Colorectal**        1931590           10.7           0
# 4   4.0      Prostate        1414259            7.8           0
#
#    Female_Percentege  Male_Case  Male_Percentege
# 0                0.0  9,342,957              0.0
# 1               25.8          0              0.0
# 2                8.8  1,435,943             15.4
# 3                0.0  1,065,960             11.4
# 4                0.0  1,414,259             15.1

# %%
df['Rank']=df['Rank'].astype(int)

# %%
df['Newcasesin2020']=df['Newcasesin2020'].astype(int)

# %%
df['FEMALE_CASE']=df['FEMALE_CASE'].str.replace(",","")
df['Male_Case']=df['Male_Case'].str.replace(",","")

# %%
df.isna().sum()
# Out:
# Rank                 0
# Cancer               0
# Newcasesin2020       0
# %ofallcancers        0
# FEMALE_CASE          5
# Female_Percentege    0
# Male_Case            7
# Male_Percentege      0
# dtype: int64

# %%
df.fillna(0,inplace=True)
df['FEMALE_CASE']=df['FEMALE_CASE'].astype(int)
df['Male_Case']=df['Male_Case'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               35 non-null     int32
#  1   Cancer             35 non-null     object
#  2   Newcasesin2020     35 non-null     int32
#  3   %ofallcancers      35 non-null     float64
#  4   FEMALE_CASE        35 non-null     int32
#  5   Female_Percentege  35 non-null     float64
#  6   Male_Case          35 non-null     int32
#  7   Male_Percentege    35 non-null     float64
# dtypes: float64(3), int32(4), object(1)
# memory usage: 1.8+ KB

# %%
df.iloc[:,:]
# Out:
#     Rank                         Cancer  Newcasesin2020  %ofallcancers  \
# 0      0                   All cancers*        18094716          100.0
# 1      1                         Breast         2261419           12.5
# 2      2                           Lung         2261771           12.2
# 3      3                   Colorectal**         1931590           10.7
# 4      4                       Prostate         1414259            7.8
# 5      5                        Stomach         1089103            6.0
# 6      6                          Liver          905677            5.0
# 7      7                   Cervix uteri          604127            3.3
# 8      8                     Oesophagus          604100            3.3
# 9      9                        Thyroid          586202            3.2
# 10    10                        Bladder          573278            3.2
# 11    11           Non-Hodgkin lymphoma          544352            3.0
# ...

# %%
df.rename(columns={'%ofallcancers':'percent_of_all','FEMALE_CASE':'Female_Cases','Newcasesin2020':'New_Cases_in_2020'})
# Out:
#     Rank                         Cancer  New_Cases_in_2020  percent_of_all  \
# 0      0                   All cancers*           18094716           100.0
# 1      1                         Breast            2261419            12.5
# 2      2                           Lung            2261771            12.2
# 3      3                   Colorectal**            1931590            10.7
# 4      4                       Prostate            1414259             7.8
# 5      5                        Stomach            1089103             6.0
# 6      6                          Liver             905677             5.0
# 7      7                   Cervix uteri             604127             3.3
# 8      8                     Oesophagus             604100             3.3
# 9      9                        Thyroid             586202             3.2
# 10    10                        Bladder             573278             3.2
# ...

# %%
df.head()
# Out:
#    Rank        Cancer  Newcasesin2020  %ofallcancers  FEMALE_CASE  \
# 0     0  All cancers*        18094716          100.0      8751759
# 1     1        Breast         2261419           12.5      2261419
# 2     2          Lung         2261771           12.2       770828
# 3     3  Colorectal**         1931590           10.7            0
# 4     4      Prostate         1414259            7.8            0
#
#    Female_Percentege  Male_Case  Male_Percentege
# 0                0.0    9342957              0.0
# 1               25.8          0              0.0
# 2                8.8    1435943             15.4
# 3                0.0    1065960             11.4
# 4                0.0    1414259             15.1

# %%
df.drop_duplicates(inplace=True)

# %%
df.to_csv('Cancer_Data',index=False)
